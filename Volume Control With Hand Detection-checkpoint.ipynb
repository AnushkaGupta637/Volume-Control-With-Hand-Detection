# %%
pip install pycaw comtypes mediapipe opencv-python
# Out:
# Collecting pycaw
#   Downloading pycaw-20240210-py3-none-any.whl (24 kB)
# Requirement already satisfied: comtypes in c:\users\anushka gupta\anaconda3\lib\site-packages (1.1.10)
# Collecting mediapipe
#   Downloading mediapipe-0.10.20-cp39-cp39-win_amd64.whl (50.9 MB)
#      -------------------------------------- 50.9/50.9 MB 967.6 kB/s eta 0:00:00
# Requirement already satisfied: opencv-python in c:\users\anushka gupta\anaconda3\lib\site-packages (4.10.0.84)
# Requirement already satisfied: psutil in c:\users\anushka gupta\anaconda3\lib\site-packages (from pycaw) (5.9.0)
# Requirement already satisfied: protobuf<5,>=4.25.3 in c:\users\anushka gupta\anaconda3\lib\site-packages (from mediapipe) (4.25.3)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\anushka gupta\anaconda3\lib\site-packages (from mediapipe) (21.4.0)
# Requirement already satisfied: numpy<2 in c:\users\anushka gupta\anaconda3\lib\site-packages (from mediapipe) (1.24.0)
# Collecting sentencepiece
#   Downloading sentencepiece-0.2.0-cp39-cp39-win_amd64.whl (991 kB)
#      ------------------------------------ 991.5/991.5 kB 966.8 kB/s eta 0:00:00
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\anushka gupta\anaconda3\lib\site-packages (from mediapipe) (23.5.26)
# Collecting sounddevice>=0.4.4
#   Downloading sounddevice-0.5.1-py3-none-win_amd64.whl (363 kB)
#      -------------------------------------- 363.6/363.6 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: absl-py in c:\users\anushka gupta\anaconda3\lib\site-packages (from mediapipe) (2.1.0)
# Collecting jaxlib
#   Downloading jaxlib-0.4.30-cp39-cp39-win_amd64.whl (51.9 MB)
#      -------------------------------------- 51.9/51.9 MB 484.9 kB/s eta 0:00:00
# Collecting jax
#   Downloading jax-0.4.30-py3-none-any.whl (2.0 MB)
#      ---------------------------------------- 2.0/2.0 MB 499.7 kB/s eta 0:00:00
# Requirement already satisfied: matplotlib in c:\users\anushka gupta\anaconda3\lib\site-packages (from mediapipe) (3.5.2)
# Collecting opencv-contrib-python
#   Downloading opencv_contrib_python-4.10.0.84-cp37-abi3-win_amd64.whl (45.5 MB)
#      -------------------------------------- 45.5/45.5 MB 707.4 kB/s eta 0:00:00
# Requirement already satisfied: CFFI>=1.0 in c:\users\anushka gupta\anaconda3\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.15.1)
# Requirement already satisfied: scipy>=1.9 in c:\users\anushka gupta\anaconda3\lib\site-packages (from jax->mediapipe) (1.13.1)
# Requirement already satisfied: opt-einsum in c:\users\anushka gupta\anaconda3\lib\site-packages (from jax->mediapipe) (3.3.0)
# Requirement already satisfied: importlib-metadata>=4.6 in c:\users\anushka gupta\anaconda3\lib\site-packages (from jax->mediapipe) (4.11.3)
# Requirement already satisfied: ml-dtypes>=0.2.0 in c:\users\anushka gupta\anaconda3\lib\site-packages (from jax->mediapipe) (0.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\anushka gupta\anaconda3\lib\site-packages (from matplotlib->mediapipe) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\anushka gupta\anaconda3\lib\site-packages (from matplotlib->mediapipe) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\anushka gupta\anaconda3\lib\site-packages (from matplotlib->mediapipe) (9.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\anushka gupta\anaconda3\lib\site-packages (from matplotlib->mediapipe) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\anushka gupta\anaconda3\lib\site-packages (from matplotlib->mediapipe) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\anushka gupta\anaconda3\lib\site-packages (from matplotlib->mediapipe) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\anushka gupta\anaconda3\lib\site-packages (from matplotlib->mediapipe) (0.11.0)
# Requirement already satisfied: pycparser in c:\users\anushka gupta\anaconda3\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)
# Requirement already satisfied: zipp>=0.5 in c:\users\anushka gupta\anaconda3\lib\site-packages (from importlib-metadata>=4.6->jax->mediapipe) (3.8.0)
# Requirement already satisfied: six>=1.5 in c:\users\anushka gupta\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# Installing collected packages: sentencepiece, pycaw, opencv-contrib-python, sounddevice, jaxlib, jax, mediapipe
# Successfully installed jax-0.4.30 jaxlib-0.4.30 mediapipe-0.10.20 opencv-contrib-python-4.10.0.84 pycaw-20240210 sentencepiece-0.2.0 sounddevice-0.5.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade mediapipe
# Out:
# Requirement already satisfied: mediapipe in c:\users\anushka gupta\anaconda3\lib\site-packages (0.10.20)
# Requirement already satisfied: protobuf<5,>=4.25.3 in c:\users\anushka gupta\anaconda3\lib\site-packages (from mediapipe) (4.25.3)
# Requirement already satisfied: jax in c:\users\anushka gupta\anaconda3\lib\site-packages (from mediapipe) (0.4.30)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\anushka gupta\anaconda3\lib\site-packages (from mediapipe) (23.5.26)
# Requirement already satisfied: matplotlib in c:\users\anushka gupta\anaconda3\lib\site-packages (from mediapipe) (3.5.2)
# Requirement already satisfied: opencv-contrib-python in c:\users\anushka gupta\anaconda3\lib\site-packages (from mediapipe) (4.10.0.84)
# Requirement already satisfied: sentencepiece in c:\users\anushka gupta\anaconda3\lib\site-packages (from mediapipe) (0.2.0)
# Requirement already satisfied: absl-py in c:\users\anushka gupta\anaconda3\lib\site-packages (from mediapipe) (2.1.0)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\anushka gupta\anaconda3\lib\site-packages (from mediapipe) (0.5.1)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\anushka gupta\anaconda3\lib\site-packages (from mediapipe) (21.4.0)
# Requirement already satisfied: jaxlib in c:\users\anushka gupta\anaconda3\lib\site-packages (from mediapipe) (0.4.30)
# Requirement already satisfied: numpy<2 in c:\users\anushka gupta\anaconda3\lib\site-packages (from mediapipe) (1.24.0)
# Requirement already satisfied: CFFI>=1.0 in c:\users\anushka gupta\anaconda3\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.15.1)
# Requirement already satisfied: scipy>=1.9 in c:\users\anushka gupta\anaconda3\lib\site-packages (from jax->mediapipe) (1.13.1)
# Requirement already satisfied: opt-einsum in c:\users\anushka gupta\anaconda3\lib\site-packages (from jax->mediapipe) (3.3.0)
# Requirement already satisfied: importlib-metadata>=4.6 in c:\users\anushka gupta\anaconda3\lib\site-packages (from jax->mediapipe) (4.11.3)
# Requirement already satisfied: ml-dtypes>=0.2.0 in c:\users\anushka gupta\anaconda3\lib\site-packages (from jax->mediapipe) (0.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\anushka gupta\anaconda3\lib\site-packages (from matplotlib->mediapipe) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\anushka gupta\anaconda3\lib\site-packages (from matplotlib->mediapipe) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\anushka gupta\anaconda3\lib\site-packages (from matplotlib->mediapipe) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\anushka gupta\anaconda3\lib\site-packages (from matplotlib->mediapipe) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\anushka gupta\anaconda3\lib\site-packages (from matplotlib->mediapipe) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\anushka gupta\anaconda3\lib\site-packages (from matplotlib->mediapipe) (9.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\anushka gupta\anaconda3\lib\site-packages (from matplotlib->mediapipe) (4.25.0)
# Requirement already satisfied: pycparser in c:\users\anushka gupta\anaconda3\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)
# Requirement already satisfied: zipp>=0.5 in c:\users\anushka gupta\anaconda3\lib\site-packages (from importlib-metadata>=4.6->jax->mediapipe) (3.8.0)
# Requirement already satisfied: six>=1.5 in c:\users\anushka gupta\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2 
import mediapipe as mp
from math import hypot
from ctypes import cast, POINTER
from comtypes import CLSCTX_ALL
from pycaw.pycaw import AudioUtilities, IAudioEndpointVolume
import numpy as np

# %%
import cv2 
import mediapipe as mp
from math import hypot
from ctypes import cast, POINTER
from comtypes import CLSCTX_ALL
from pycaw.pycaw import AudioUtilities, IAudioEndpointVolume
import numpy as np 

cap = cv2.VideoCapture(0)

mpHands = mp.solutions.hands 
hands = mpHands.Hands()
mpDraw = mp.solutions.drawing_utils


devices = AudioUtilities.GetSpeakers()
interface = devices.Activate(IAudioEndpointVolume._iid_, CLSCTX_ALL, None)
volume = cast(interface, POINTER(IAudioEndpointVolume))

volMin,volMax = volume.GetVolumeRange()[:2]

while True:
    success,img = cap.read()
    imgRGB = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    results = hands.process(imgRGB)

    lmList = []
    if results.multi_hand_landmarks:
        for handlandmark in results.multi_hand_landmarks:
            for id,lm in enumerate(handlandmark.landmark):
                h,w,_ = img.shape
                cx,cy = int(lm.x*w),int(lm.y*h)
                lmList.append([id,cx,cy]) 
            mpDraw.draw_landmarks(img,handlandmark,mpHands.HAND_CONNECTIONS)
    
    if lmList != []:
        x1,y1 = lmList[4][1],lmList[4][2]
        x2,y2 = lmList[8][1],lmList[8][2]

        cv2.circle(img,(x1,y1),4,(255,0,0),cv2.FILLED)
        cv2.circle(img,(x2,y2),4,(255,0,0),cv2.FILLED)
        cv2.line(img,(x1,y1),(x2,y2),(255,0,0),3)

        length = hypot(x2-x1,y2-y1)

        vol = np.interp(length,[15,220],[volMin,volMax])
        print(vol,length)
        volume.SetMasterVolumeLevel(vol, None)

        # Hand range 15 - 220
        # Volume range -63.5 - 0.0
        
    cv2.imshow('Image',img)
    if cv2.waitKey(1) & 0xff==ord('q'):
        break
